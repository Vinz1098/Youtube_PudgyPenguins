# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinz1098/Vinayak02/blob/main/BerTopic_Integrate_Top20Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Choose the Excel file from your local system to upload
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a176936-3f36-4de9-bcea-a9427a30871e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a176936-3f36-4de9-bcea-a9427a30871e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Assuming the name of your uploaded file is 'your_file.xlsx'
file_name = 'YouTube_Data.xlsx'

# Read the uploaded Excel file
data = pd.read_excel('YouTube_Data.xlsx')

# Display the contents of the Excel file
print(data)
# Out:
#                Query     Video ID  \
# 0     Pudgy Penguins  _GbfatW2vjw
# 1     Pudgy Penguins  _GbfatW2vjw
# 2     Pudgy Penguins  _GbfatW2vjw
# 3     Pudgy Penguins  _GbfatW2vjw
# 4     Pudgy Penguins  _GbfatW2vjw
# ...              ...          ...
# 1771  Pudgy Penguins  3qeLo0oU0nc
# 1772  Pudgy Penguins  3qeLo0oU0nc
# 1773  Pudgy Penguins  3qeLo0oU0nc
# 1774  Pudgy Penguins  3qeLo0oU0nc
# 1775  Pudgy Penguins  3qeLo0oU0nc
#
#                                                   Title  \
# 0                         NFT DropList: Pudgy Penguins,
# 1                         NFT DropList: Pudgy Penguins,
# 2                         NFT DropList: Pudgy Penguins,
# 3                         NFT DropList: Pudgy Penguins,
# 4                         NFT DropList: Pudgy Penguins,
# ...                                                 ...
# 1771  MAJOR MARKET PUMP | Blackrock ETH ETF, Roblox ...
# 1772  MAJOR MARKET PUMP | Blackrock ETH ETF, Roblox ...
# ...

# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 17.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.8 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic

# Initialize BERTopic model with desired parameters
model = BERTopic(top_n_words=30, nr_topics=50, n_gram_range=(1, 1))

# Assuming 'Clean-Comment' is the column containing the text data
# Fit the model on your 'Clean-Comment' column
topics, _ = model.fit_transform(data['Clean-Comment'])

# %%
model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Get topics and their counts
topic_counts = model.get_topic_info()

# Display topics and their counts
print(topic_counts)
# Out:
#     Topic  Count                                     Name  \
# 0      -1    667                       -1_like_br_nft_one
# 1       0     12            0_banger_another_youtube_past
# 2       1     14    1_gang_assertive_burglars_vloggguuuuu
# 3       2     21              2_metaverse_games_game_play
# 4       3     18                3_pengu_pengus_kuchi_abis
# 5       4     32    4_good_excellent_advertising_stupidly
# 6       5     19           5_lil_pudgys_collection_really
# 7       6     26                  6_pudgy_gt_pudgies_miss
# 8       7     60                  7_cute_blind_huddle_cat
# 9       8     15               8_discord_sushi_gutta_blah
# 10      9     12             9_mint_yogapetz_minted_mints
# 11     10     65                10_luca_goat_team_killing
# 12     11     26        11_interview_questions_luca_great
# 13     12     19            12_desmond_ben_benjamin_muted
# 14     13     12             13_walmart_scammer_omega_big
# ...

# %%
import pandas as pd

# Adjust the display settings to show more characters
pd.set_option('display.max_colwidth', None)

# Initialize an empty list to store top words data
top_words_data = []

# Assuming 'model' and 'topic_freq' are already defined from your previous code
# Assuming 'top_n_topics' and 'top_n_words' are defined

top_n_topics = 50  # Number of topics to visualize
top_n_words = 20  # Number of top words to display for each topic

for topic_id in range(top_n_topics):
    if topic_id in topic_freq.index and not isinstance(topic_freq.loc[topic_id], int):
        top_words = model.get_topic(topic_id)

        # Ensure that top_words is a list of tuples before iterating
        if isinstance(top_words, list) and all(isinstance(item, tuple) for item in top_words):
            words_list = [word for word, _ in top_words]
            top_words_data.append((f"Topic {topic_id}", ", ".join(words_list[:top_n_words])))
        else:
            top_words_data.append((f"Topic {topic_id}", "No top words available"))  # Add a message for unexpected data types or no top words

# Create a DataFrame with "Index Topic" and "20 Freq Words" columns
top_words_df = pd.DataFrame(top_words_data, columns=["Index Topic", "20 Freq Words"])

# Print the DataFrame
print(top_words_df)
# Out:
#    Index Topic  \
# 0      Topic 0
# 1      Topic 1
# 2      Topic 2
# 3      Topic 3
# 4      Topic 4
# 5      Topic 5
# 6      Topic 6
# 7      Topic 7
# 8      Topic 8
# 9      Topic 9
# 10    Topic 10
# 11    Topic 11
# 12    Topic 12
# 13    Topic 13
# 14    Topic 14
# 15    Topic 15
# 16    Topic 16
# 17    Topic 17
# 18    Topic 18
# 19    Topic 19
# 20    Topic 20
# 21    Topic 21
# 22    Topic 22
# 23    Topic 23
# 24    Topic 24
# 25    Topic 25
# 26    Topic 26
# 27    Topic 27
# 28    Topic 28
# 29    Topic 29
# 30    Topic 30
# 31    Topic 31
# 32    Topic 32
# 33    Topic 33
# 34    Topic 34
# 35    Topic 35
# 36    Topic 36
# 37    Topic 37
# 38    Topic 38
#
#                                                                                                                                                                                                                 20 Freq Words
# ...

# %%
import pandas as pd

# Assuming 'data' DataFrame contains 'Clean-Comment' column
# Assuming 'model.fit_transform(data['Clean-Comment'])' is executed and 'topics', 'topic_freq' are obtained

# Assuming 'top_n_topics' is defined
top_n_topics = 50  # Number of topics to visualize

# Initialize an empty list to store top comments data
top_comments_data = []

# Check if 'topics' is a valid array
if isinstance(topics, list):
    for topic_id in range(top_n_topics):
        if topic_id in topic_freq.index and not isinstance(topic_freq.loc[topic_id], int):
            # Filter rows based on the condition (topics == topic_id)
            selected_comments = data[[topic == topic_id for topic in topics]]['Clean-Comment'].head(20).tolist()

            # Combine the comments into a single string
            comments_text = "\n".join(selected_comments)

            top_comments_data.append(comments_text)
        else:
            top_comments_data.append("")  # Add an empty string if topic_id is not in topic_freq index
else:
    print("'topics' variable is not in the expected format. Check the content or how it's generated.")

# Create a DataFrame with "Top 20 Comment" column
top_comments_df = pd.DataFrame(top_comments_data, columns=["Top 20 Comment"])

# Print the DataFrame containing the top 20 comments for each topic
print(top_comments_df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Save the DataFrame to a CSV file
final_df.to_csv('Top20Words.csv', index=False)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1aa57156-edcf-4fca-ac3b-61852967db85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1aa57156-edcf-4fca-ac3b-61852967db85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Read the uploaded file into a Pandas DataFrame
df = pd.read_csv(next(iter(uploaded)))

# Display the first few rows of the DataFrame to verify the data
print(df.head())
# Out:
#   Index Topic  \
# 0     Topic 0
# 1     Topic 1
# 2     Topic 2
# 3     Topic 3
# 4     Topic 4
#
#                                                                                                                                                           20 Freq Words  \
# 0                        banger, another, youtube, past, tee, meaningful, jr, bowser, bangers, igloo, href, pick, amp, asking, video, www, missed, favorite, edit, idea
# 1  gang, assertive, burglars, vloggguuuuu, snipers, habibi, tch, state, enemies, clowns, galaktic, killer, nyc, promising, hodl, straight, energy, live, sending, vibes
# 2            metaverse, games, game, play, playing, part, win, enjoy, thing, fun, real, abandon, hellopets, firewall, specific, og, errors, pvp, individually, horrible
# 3          pengu, pengus, kuchi, abis, keren, fuckin, chill, boss, goooooo, squidgrow, yey, karafuruuuu, karafuru, kuromi, penguions, pengys, kuu, pengwing, peng, mood
# ...

# %%
# !pip install openai==0.28.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai

openai.api_key = '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'

for idx2, row in df.iterrows():

  print(f"Summarising comment  ... {idx2}")

# Select the specific column for analysis
  column_to_analyze = row['20 Freq Words']

  completion = openai.ChatCompletion.create(model="gpt-3.5-turbo-16k", messages = [{"role": "user", "content":  f"Provide a phrase of not more than 10 words to capture the latent meaning in following terms delimited with triple backticks generated from the BertTopic model :'''{column_to_analyze}'''"}])

  df.at[idx2,'Terms_Label'] = completion.choices[0].message.content

# Print GPT-3.5 generated analysis for the specific column
  print(completion.choices[0].message.content)

  column_to_analyze = row['Top 20 Comment']

  completion = openai.ChatCompletion.create(model="gpt-3.5-turbo-16k", messages = [{"role": "user", "content":  f"Provide a phrase of not more than 15 words to summarise the following text delimited with triple backtricks which comprises the most representative comments associated with a BertTopic :'''{column_to_analyze}'''"}])

  df.at[idx2,'Comment_Label'] = completion.choices[0].message.content

# Print GPT-3.5 generated analysis for the specific column
  print(completion.choices[0].message.content)


df.to_excel('PudgyBertTopicsLabelled20Words.xlsx', index=False)

from google.colab import files
files.download('PudgyBertTopicsLabelled20Words.xlsx')
# Out:
# Summarising comment  ... 0
# "Discovering viral videos and creative ideas on YouTube's platform."
# "Banger videos from a favorite YouTube channel keep coming, with amazing quality and meaningful content."
# Summarising comment  ... 1
# Assertive gang of burglars sending promising vibes, straight from NYC.
# Promising hodl gang with low floor, enthusiastic and diverse with lots of love vibes.
# Summarising comment  ... 2
# "Immersive virtual world where gaming brings joy and competition."
# The text discusses the popularity and enjoyment of playing games in the metaverse.
# Summarising comment  ... 3
# Kawaii penguins having fun with colorful and cool vibes.
# Pengu love and fandom shines through in colorful and impressive ways, constantly impressing and cheering on.
# Summarising comment  ... 4
# "The advertisement exceeded expectations with an incredible offer."
# The text is a collection of positive and enthusiastic comments about a topic or product.
# Summarising comment  ... 5
# ...
